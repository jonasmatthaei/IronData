# %%
import pandas as pd

df = pd.read_csv (r'irondata.csv')
print (df)
# Out:
#                                    Name                Date        Day  \
# 0                      Zwift - FTP Test  September 16, 2022     Friday
# 1                Zwift Training Program  September 17, 2022   Saturday
# 2   Zwift - After being sick for 8 days  September 25, 2022     Sunday
# 3                           Zwift - 4x5  September 26, 2022     Monday
# 4                  Zwift - 3x Flatroute  September 28, 2022  Wednesday
# 5           Outdoor - First time x Vlad  September 30, 2022     Friday
# 6           Zwift - First Bike and Run      October 5, 2022  Wednesday
# 7                 First Run - Beach Run   September 4, 2022     Sunday
# 8                      Second Beach Run   September 5, 2022     Monday
# 9                         6k with Matt    September 8, 2022   Thursday
# 10                     4k Baseline-Test  September 13, 2022    Tuesday
# 11                             First 7k  September 14, 2022  Wednesday
# ...

# %%
y = df["Heart Rate Average"]
y
# Out:
# 0       NaN
# 1     150.0
# 2     122.0
# 3     141.0
# 4     145.0
# 5     154.0
# 6     146.0
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12    179.0
# 13    177.0
# 14    167.0
# 15    134.0
# Name: Heart Rate Average, dtype: float64

# %%
X = df["Date"]
X
# Out:
# 0     September 16, 2022
# 1     September 17, 2022
# 2     September 25, 2022
# 3     September 26, 2022
# 4     September 28, 2022
# 5     September 30, 2022
# 6        October 5, 2022
# 7      September 4, 2022
# 8      September 5, 2022
# 9      September 8, 2022
# 10    September 13, 2022
# 11    September 14, 2022
# 12    September 27, 2022
# 13       October 3, 2022
# 14       October 5, 2022
# 15       October 7, 2022
# Name: Date, dtype: object

# %%
bike_df = df.loc[df['Sport'] == "Bike"]
bike_df
# Out:
#                                   Name                Date        Day  \
# 0                     Zwift - FTP Test  September 16, 2022     Friday
# 1               Zwift Training Program  September 17, 2022   Saturday
# 2  Zwift - After being sick for 8 days  September 25, 2022     Sunday
# 3                          Zwift - 4x5  September 26, 2022     Monday
# 4                 Zwift - 3x Flatroute  September 28, 2022  Wednesday
# 5          Outdoor - First time x Vlad  September 30, 2022     Friday
# 6          Zwift - First Bike and Run      October 5, 2022  Wednesday
#
#    Distance  Duration Feelings Status Sport  Calories  Elevation  Pace  \
# 0     16.40        37   Medium    Yes  Bike     239.0        NaN   NaN
# 1     30.76        67   High 🔥    Yes  Bike     521.0      120.0  27.5
# 2     13.02        30   Medium    Yes  Bike     235.0       99.0  25.9
# 3     23.73        48   High 🔥    Yes  Bike     512.0       97.0  29.5
# ...

# %%
bike_df.drop(['Kadenz', 'Beckenlänge', 'Bahnen', 'Züge-100m'], axis = 1, inplace = True)
# Out:
# /Users/jonasmatthaei/.pyenv/versions/3.8.13/envs/lewagon1/lib/python3.8/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
bike_df
# Out:
#                                   Name                Date        Day  \
# 0                     Zwift - FTP Test  September 16, 2022     Friday
# 1               Zwift Training Program  September 17, 2022   Saturday
# 2  Zwift - After being sick for 8 days  September 25, 2022     Sunday
# 3                          Zwift - 4x5  September 26, 2022     Monday
# 4                 Zwift - 3x Flatroute  September 28, 2022  Wednesday
# 5          Outdoor - First time x Vlad  September 30, 2022     Friday
# 6          Zwift - First Bike and Run      October 5, 2022  Wednesday
#
#    Distance  Duration Feelings Status Sport  Calories  Elevation  Pace  \
# 0     16.40        37   Medium    Yes  Bike     239.0        NaN   NaN
# 1     30.76        67   High 🔥    Yes  Bike     521.0      120.0  27.5
# 2     13.02        30   Medium    Yes  Bike     235.0       99.0  25.9
# 3     23.73        48   High 🔥    Yes  Bike     512.0       97.0  29.5
# ...

# %%
run_df = df.loc[df['Sport'] == "Run"]
run_df
# Out:
#                      Name                Date        Day  Distance  Duration  \
# 7   First Run - Beach Run   September 4, 2022     Sunday       3.0        16
# 8        Second Beach Run   September 5, 2022     Monday       3.0        19
# 9           6k with Matt    September 8, 2022   Thursday       6.3        35
# 10       4k Baseline-Test  September 13, 2022    Tuesday       4.0        19
# 11               First 7k  September 14, 2022  Wednesday       7.3        42
# 12         4k Morning Run  September 27, 2022    Tuesday       4.0        20
# 13   Afternoon Run x Juli     October 3, 2022     Monday       4.7        23
# 14     First Bike and Run     October 5, 2022  Wednesday       5.0        26
#
#    Feelings Status Sport  Calories  Elevation  Pace  Heart Rate Average  \
# 7    High 🔥    Yes   Run       NaN        8.0  5.26                 NaN
# 8    Medium    Yes   Run       NaN        9.0  6.12                 NaN
# ...

# %%
run_df.drop(['Kadenz', 'Average Watts', 'Beckenlänge', 'Bahnen', 'Züge-100m'], axis = 1, inplace = True)
# Out:
# /Users/jonasmatthaei/.pyenv/versions/3.8.13/envs/lewagon1/lib/python3.8/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
swim_df = df.loc[df['Sport'] == "Swim"]
swim_df
# Out:
#           Name             Date     Day  Distance  Duration Feelings Status  \
# 15  First Swim  October 7, 2022  Friday     770.0        57   Medium    Yes
#
#    Sport  Calories  Elevation  Pace  Heart Rate Average  Starttime  \
# 15  Swim     205.0        NaN  7.18               134.0       12.5
#
#     Average Watts  Kadenz  Beckenlänge  Bahnen  Züge-100m
# 15            NaN     NaN         25.0    32.0       50.0

# %%
swim_df.drop(['Elevation', 'Average Watts', 'Kadenz'], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/9s/z007hmbn17dbjzgtyb_yx32r0000gn/T/ipykernel_81254/3659853370.py in <module>
# ----> 1 swim_df.drop(['Elevation', 'Average Watts', 'Kadenz'], axis = 1, inplace = True)
#
# ~/.pyenv/versions/3.8.13/envs/lewagon1/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.pyenv/versions/3.8.13/envs/lewagon1/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
swim_df
# Out:
#           Name             Date     Day  Distance  Duration Feelings Status  \
# 15  First Swim  October 7, 2022  Friday     770.0        57   Medium    Yes
#
#    Sport  Calories  Pace  Heart Rate Average  Starttime  Beckenlänge  Bahnen  \
# 15  Swim     205.0  7.18               134.0       12.5         25.0    32.0
#
#     Züge-100m
# 15       50.0

# %% [markdown]
# ## Visualisierung

# %%
datum = bike_df["Date"]

# %%
bike_df["Heart Rate Average"]
# Out:
# 0      NaN
# 1    150.0
# 2    122.0
# 3    141.0
# 4    145.0
# 5    154.0
# 6    146.0
# Name: Heart Rate Average, dtype: float64

# %%
bike_df.dropna(inplace=True)
# Out:
# /Users/jonasmatthaei/.pyenv/versions/3.8.13/envs/lewagon1/lib/python3.8/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %% [markdown]
# ### Bike

# %%
import matplotlib.pyplot as plt
plt.plot(bike_df["Date"], bike_df["Average Watts"])

# %%
plt.plot(bike_df["Date"], bike_df["Pace"])

# %%
plt.plot(bike_df["Date"], bike_df["Heart Rate Average"])

# %%
plt.plot(bike_df["Date"], bike_df["Average Watts"])

# %% [markdown]
# ### Run

# %%
run_df
# Out:
#                     Name                Date        Day  Distance  Duration  \
# 12        4k Morning Run  September 27, 2022    Tuesday       4.0        20
# 13  Afternoon Run x Juli     October 3, 2022     Monday       4.7        23
# 14    First Bike and Run     October 5, 2022  Wednesday       5.0        26
#
#    Feelings Status Sport  Calories  Elevation  Pace  Heart Rate Average  \
# 12   High 🔥    Yes   Run     252.0       11.0  4.59               179.0
# 13   High 🔥    Yes   Run     220.0       28.0  4.58               177.0
# 14   Medium    Yes   Run     312.0       27.0  5.05               167.0
#
#     Starttime
# 12       7.90
# 13      18.90
# 14      15.25

# %%
plt.plot(run_df["Date"], run_df["Pace"])

# %%
HR_run = run_df.dropna()

# %%
HR_run
# Out:
#                     Name                Date        Day  Distance  Duration  \
# 12        4k Morning Run  September 27, 2022    Tuesday       4.0        20
# 13  Afternoon Run x Juli     October 3, 2022     Monday       4.7        23
# 14    First Bike and Run     October 5, 2022  Wednesday       5.0        26
#
#    Feelings Status Sport  Calories  Elevation  Pace  Heart Rate Average  \
# 12   High 🔥    Yes   Run     252.0       11.0  4.59               179.0
# 13   High 🔥    Yes   Run     220.0       28.0  4.58               177.0
# 14   Medium    Yes   Run     312.0       27.0  5.05               167.0
#
#     Starttime
# 12       7.90
# 13      18.90
# 14      15.25

# %%
plt.plot(HR_run["Date"], HR_run["Heart Rate Average"])

# %% [markdown]
# ## Correlation

# %%
HR_run.corr()
# Out:
#                     Distance  Duration  Calories  Elevation      Pace  \
# Distance            1.000000  0.974355  0.453401   0.939689  0.718480
# Duration            0.974355  1.000000  0.642333   0.838628  0.856565
# Calories            0.453401  0.642333  1.000000   0.121203  0.945706
# Elevation           0.939689  0.838628  0.121203   1.000000  0.437250
# Pace                0.718480  0.856565  0.945706   0.437250  1.000000
# Heart Rate Average -0.828494 -0.933257 -0.874770  -0.586991 -0.984762
# Starttime           0.808955  0.655928 -0.157192   0.961235  0.172326
#
#                     Heart Rate Average  Starttime
# Distance                     -0.828494   0.808955
# Duration                     -0.933257   0.655928
# Calories                     -0.874770  -0.157192
# Elevation                    -0.586991   0.961235
# Pace                         -0.984762   0.172326
# Heart Rate Average            1.000000  -0.341008
# Starttime                    -0.341008   1.000000

# %%
import seaborn as sns

# %%
run_df
# Out:
#                      Name                Date        Day  Distance  Duration  \
# 7   First Run - Beach Run   September 4, 2022     Sunday       3.0        16
# 8        Second Beach Run   September 5, 2022     Monday       3.0        19
# 9           6k with Matt    September 8, 2022   Thursday       6.3        35
# 10       4k Baseline-Test  September 13, 2022    Tuesday       4.0        19
# 11               First 7k  September 14, 2022  Wednesday       7.3        42
# 12         4k Morning Run  September 27, 2022    Tuesday       4.0        20
# 13   Afternoon Run x Juli     October 3, 2022     Monday       4.7        23
# 14     First Bike and Run     October 5, 2022  Wednesday       5.0        26
#
#    Feelings Status Sport  Calories  Elevation  Pace  Heart Rate Average  \
# 7    High 🔥    Yes   Run       NaN        8.0  5.26                 NaN
# 8    Medium    Yes   Run       NaN        9.0  6.12                 NaN
# ...

# %%
run_df.drop(['Name', 'Date', 'Day', 'Feelings', 'Sport', 'Status'], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/9s/z007hmbn17dbjzgtyb_yx32r0000gn/T/ipykernel_81254/2906347949.py in <module>
# ----> 1 run_df.drop(['Name', 'Date', 'Day', 'Feelings', 'Sport', 'Status'], axis = 1, inplace = True)
#
# ~/.pyenv/versions/3.8.13/envs/lewagon1/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.pyenv/versions/3.8.13/envs/lewagon1/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
run_df
# Out:
#     Distance  Duration  Calories  Elevation  Pace  Heart Rate Average  \
# 7        3.0        16       NaN        8.0  5.26                 NaN
# 8        3.0        19       NaN        9.0  6.12                 NaN
# 9        6.3        35       NaN       51.0  5.35                 NaN
# 10       4.0        19       NaN       14.0  4.50                 NaN
# 11       7.3        42       NaN       27.0  5.49                 NaN
# 12       4.0        20     252.0       11.0  4.59               179.0
# 13       4.7        23     220.0       28.0  4.58               177.0
# 14       5.0        26     312.0       27.0  5.05               167.0
#
#     Starttime
# 7        6.75
# 8        6.50
# 9        7.50
# 10       7.70
# 11       6.25
# 12       7.90
# 13      18.90
# 14      15.25

# %%
sns.he
